# %% [markdown]
# # Using Tweepy for Fun and Profit

# %% [markdown]
# Tweepy is a library that lets you use Twitter via Python. Here are all the docs for using it: http://tweepy.readthedocs.org/en/v3.5.0/
#
# Because Tweepy is not part of the default Anaconda distribution we need to install is separately. Run the next cell and that should download and install the library so that you can use it.

# %%
! pip install tweepy
# Out:
# Collecting tweepy
#   Using cached tweepy-3.5.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.4.3 in /anaconda/lib/python2.7/site-packages (from tweepy)
# Collecting requests-oauthlib>=0.4.1 (from tweepy)
#   Downloading requests_oauthlib-0.8.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.7.3 in /anaconda/lib/python2.7/site-packages (from tweepy)
# Collecting oauthlib>=0.6.2 (from requests-oauthlib>=0.4.1->tweepy)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-2.0.1 requests-oauthlib-0.8.0 tweepy-3.5.0

# %% [markdown]
# If everything worked, the next cell should execute with no errors.

# %%
import tweepy

# %% [markdown]
# Before we can really DO anything with Tweepy we need to authenticate it. Basically we need to log into Twitter with the right credentials. To create your own account and authenticate your own bot continue with the following instructions.
#
# **Create a Twitter Account**
#
# The first step to doing this is to create a Twitter account that you can use. Unless you want to pollute your own Twitter timeline (if you already use it) then you'll want to create a new account. A helpful tip from Dan Nguyen at Stanford is that it's easiest to register the new Twitter account with the email address of yournormalname+mytwitterbot@gmail.com. GMail will redirect all of those emails to your normal gmail account but Twitter thinks its a unique email address.
#
# You will also have to add a phone number to the account which is verified via text message in order to proceed to the next step.
#
# ** Create a Twitter App**
#
# Follow the instructions here: [http://www.compjour.org/tutorials/getting-started-with-tweepy/](http://www.compjour.org/tutorials/getting-started-with-tweepy/) to create a Twitter app. We need to do this in order to get the necessary authentication tokens to log in to Twitter programmatically.
#
# You'll get four tokens that you need to copy into the code below. In general you should NOT publish these keys.

# %%
CONSUMER_KEY = "lBSmQ8m3KRaCCnVRO42MqO4vQ"
CONSUMER_SECRET = "06ci6sqCvse2T3mNM3f5Aat2srWqohxHXqRf0fBdMhXylqMCGT"
ACCESS_TOKEN = "851475089971458048-XkFWKdxlI1MIxz7vQjZnZUm9fia6Jxs"
ACCESS_TOKEN_SECRET = "d4U5WtcKpmTIoWgwshMHyVScofXSJDH3eHRAxBfwWNJSY"

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)
api.me()
# Out:
# User(screen_name='NewsSurveyBot', is_translator=False, contributors_enabled=False, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', time_zone=None, utc_offset=None, profile_text_color='333333', translator_type='none', location='', profile_background_image_url=None, profile_sidebar_border_color='C0DEED', id_str='851475089971458048', favourites_count=0, friends_count=0, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=0, listed_count=0, geo_enabled=False, profile_location=None, verified=False, profile_background_image_url_https=None, _json={'is_translator': False, 'following': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'time_zone': None, 'utc_offset': None, 'profile_text_color': '333333', 'translator_type': 'none', 'location': '', 'is_translation_enabled': False, 'profile_sidebar_border_color': 'C0DEED', 'id_str': '851475089971458048', 'favourites_count': 0, 'profile_location': None, 'contributors_enabled': False, 'profile_background_image_url': None, 'entities': {'description': {'urls': []}}, 'friends_count': 0, 'protected': False, 'followers_count': 0, 'listed_count': 0, 'geo_enabled': False, 'verified': False, 'profile_background_image_url_https': None, 'has_extended_profile': False, 'profile_use_background_image': True, 'profile_background_color': 'F5F8FA', 'statuses_count': 0, 'id': 851475089971458048, 'follow_request_sent': False, 'created_at': 'Mon Apr 10 16:40:55 +0000 2017', 'default_profile': True, 'needs_phone_verification': False, 'notifications': False, 'profile_sidebar_fill_color': 'DDEEF6', 'name': 'SurveyBot', 'default_profile_image': True, 'description': '', 'profile_background_tile': False, 'url': None, 'screen_name': 'NewsSurveyBot', 'profile_link_color': '1DA1F2', 'suspended': False, 'lang': 'en', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png'}, profile_use_background_image=True, profile_background_color='F5F8FA', statuses_count=0, id=851475089971458048, needs_phone_verification=False, follow_request_sent=False, created_at=datetime.datetime(2017, 4, 10, 16, 40, 55), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='SurveyBot', default_profile_image=True, description='', profile_background_tile=False, url=None, profile_link_color='1DA1F2', suspended=False, lang='en', profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png')

# %% [markdown]
# Now that we've authenticated we can use tweepy to make calls to the Twitter API. I can print out the latest 20 tweets from a given account by doing the following:

# %%
tweets = api.user_timeline("merrillcollege")
for tweet in tweets:
    print(tweet.created_at, " ", tweet.text)
    print("\n")
# Out:
# 2017-04-10 16:45:56   RT @gijn: A Field Guide to Fake News: 1st 3 chapters traces trajectory of #fakenews &amp;more @jwyg @bb_liliana @TommasoVenturin https://t.co/4…
#
#
# 2017-04-10 16:45:16   RT @CynthiaHenthorn: 4/29 10 am - 4 pm #MarylandDay Hornbake Plaza join @Maryland_Alumni folding &amp; packing t-shirts for @loveblanketproj. @…
#
#
# 2017-04-10 16:45:03   RT @lilyciric: Free app gives journalists a video studio on-the-go https://t.co/FmSl68fPRq https://t.co/V17zAKI3ha
#
#
# 2017-04-10 16:44:25   RT @PovichCenter: Start your Monday off right with today’s roundup! https://t.co/DrYojcBXbn Stories by @richarddeitsch, @ThomasBoswellWP, @…
#
#
# 2017-04-10 16:44:09   RT @presidentloh: Decennial re-accreditation review of #UMD was laudatory with many commendations https://t.co/OeJepm7FzM
#
#
# 2017-04-10 12:45:03   RT @AmPress: In today's Need to Know: How to report on fake news and what tactics work to improve diversity https://t.co/tIsm1yb4BO
#
#
# 2017-04-09 21:22:24   RT @joshshepperd: Giving an invited talk at @UofMaryland on Tues, on what it took to build Public Media, and why it's worth protecting http…
#
#
# 2017-04-09 14:30:45   RT @TheLeftBench: TLBTV Overtime: In their first home match in over a month, @TerpTennis downed Michigan State 5-2. @Rags_City has the reca…
#
#
# 2017-04-09 14:29:50   You are always welcome to come "home" to Knight Hall, Sung (and all our alumni!). https://t.co/5um5cHbUtD
#
#
# 2017-04-08 23:13:57   RT @ProfBlackistone: Thanks @WashWizards allowing my @merrillcollege sports reporting class to cover game tonight. How @PovichCenter rolls…
#
#
# 2017-04-08 22:27:24   RT @scholarships360: Seniors, remember this when it come to applying for #scholarships! Check out all the free money opportunities at https…
#
#
# 2017-04-08 22:00:20   RT @BonnieBernstein: Great @merrillcollege Bd of Visitors sesh. Checkin out students' state of the art gear + mtg PhD candidates! #Fearless…
#
#
# 2017-04-08 22:00:07   RT @TheLeftBench: Down goes No. 1!
# Maryland beats top-ranked Penn State at home. Recap:
# https://t.co/kOD5D3QSe5
#
#
# 2017-04-08 21:59:07   RT @MEOjobs: JOBS JOBS JOBS! Our next list of available media &amp; comm jobs comes your way Monday morning. SUBSCRIBE via https://t.co/xscyxKC…
#
#
# 2017-04-08 17:59:23   RT @TheLeftBench: The #Terps can't create scoring opportunities and drop the series opener to Nebraska in a pitchers' duel. Recap:
# https:/…
#
#
# 2017-04-08 17:58:11   RT @TheLeftBench: Maryland women's lacrosse wraps up its two-game road trip tonight against Rutgers. Preview:
# https://t.co/TrOy5WBUIZ
#
#
# 2017-04-08 17:54:31   RT @UMDSPJ: We're so proud of all our @spjregion2  finalists and winners from @vfstories @CNSmd @thedbk @merrillcollege #2017SPJ2 https://t…
#
#
# 2017-04-08 16:25:22   RT @s_waldenberg: When you're in Elon, North Carolina for #2017SPJ2 and a familiar face comes on the screen @BethanysStories #j262b https:/…
#
#
# 2017-04-08 16:24:39   RT @ndiakopoulos: How much is trust worth to FB Corp compared to optimizing for ads &amp; engagement? https://t.co/lrxHTQljY9
#
#
# 2017-04-08 11:35:30   RT @UMDSPJ: Excited to be representing @merrillcollege in Elon, NC this weekend for #spjregion2!

# %% [markdown]
# apThere's lots we can do with Tweepy. The complete API documentation is here: [http://tweepy.readthedocs.org/en/v3.5.0/api.html](http://tweepy.readthedocs.org/en/v3.5.0/api.html). But it still can't do *everything* so there are some limitations. At times it's necesary to go back to the Twitter documentation itself [https://dev.twitter.com/rest/public](https://dev.twitter.com/rest/public), and there are important details to be aware of such as rate limits which affect how often an account can tweet or how many API calls it can make in a given window of time.

# %% [markdown]
# **Sending a tweet**

# %%
# update_status function, if we add a in_reply_to_status_id parameter we can make the bot reply to another tweet. 
new_tweet = api.update_status("Hi, this is a second tweet!",in_reply_to_status_id='851480803381039104')

# %%
# Tweepy returns an object with metadata for the tweet we just sent. 
new_tweet

follow_rebecca = api.create_friendship('Beckgale')

# %% [markdown]
# **Get User Details**

# %%
import json
import pprint

# get_user
user = api.get_user(screen_name="merrillcollege")

# We can grab the json version of the object and print it 
pprint.pprint(user._json)

# %%
# And we can then access individual attributes of the user
print "Followers:",user.followers_count
print "Friends:",user.friends_count

# %% [markdown]
# **List Timeline**
#
# Can be useful if you want your bot just to pay attention to a few specific accounts.

# %%
# list_timeline
# 1st parameter is the list owner, and 2nd is the slug
# If you're on twitter the URL looks like: https://twitter.com/YuriEngelhardt/lists/dagstuhl-datadriven-story
list_tweets = api.list_timeline("YuriEngelhardt", "dagstuhl-datadriven-story", per_page=10, page=0)
for tweet in list_tweets:
    print tweet.created_at, " ", tweet.text
    print "\n"

# %%
# trends_closest
# Look up lat, long coordinates on google maps by right-clicking
latitude = 38.987004
longitude =  -76.948303
nearby_locations_with_trends = api.trends_closest(latitude, longitude)
# This gives us the nearby locations that have trending topics associated with them
print nearby_locations_with_trends[0]["woeid"]

# now to get the actual trends for washington
trends = api.trends_place(nearby_locations_with_trends[0]["woeid"])
pprint.pprint(trends)
# Out:
#   File "<ipython-input-12-e344ac5b30ac>", line 7
#     print nearby_locations_with_trends[0]["woeid"]
#                                      ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
for t in trends[0]["trends"]:
    print t["name"]

# %% [markdown]
# **Search**
#
# Let's search for the results of the first trend we found. You should be able to get up to 1000 results via the `count` parameter. There are ways to get more than that but you need to use the `since_id` parameter and do some custom code to keep track of ids.

# %%
# Get the first page of 10 results
counter = 1
to_respond_to = []
search_result = api.search('http://www.newyorker.com/humor/borowitz-report', lang="en", count=1000)
for tweet in search_result:
    print(tweet.created_at, " ", tweet.text, " ", tweet.id_str)
    to_respond_to.append(tweet.id_str)
    counter +=1 
print(counter)
# Out:
# 2017-04-10 16:24:26   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   851470941301293057
# 2017-04-10 15:24:11   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   851455780385574913
# 2017-04-09 23:30:29   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   851215770893918209
# 2017-04-09 16:44:35   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   851113625213222912
# 2017-04-09 12:43:46   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   851053022390235136
# 2017-04-09 05:51:36   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850949295989694464
# 2017-04-09 05:18:26   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850940948838100992
# 2017-04-09 04:32:20   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850929347363880960
# 2017-04-09 04:30:35   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850928906479783937
# 2017-04-09 04:27:31   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850928132962099201
# 2017-04-09 04:10:07   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850923755597688832
# 2017-04-09 03:54:07   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850919728612876288
# 2017-04-09 03:46:59   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850917933916278784
# 2017-04-09 03:31:18   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850913987915128832
# 2017-04-09 03:26:20   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850912739677659141
# 2017-04-09 03:26:00   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850912655376343040
# 2017-04-09 03:20:08   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850911176405819394
# 2017-04-09 03:16:58   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850910381774036992
# 2017-04-09 03:15:21   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850909971604795393
# 2017-04-09 03:15:12   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850909936813035520
# 2017-04-09 03:14:10   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850909677554724865
# 2017-04-09 03:14:02   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850909642955923458
# 2017-04-09 03:08:28   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850908243236974594
# 2017-04-09 03:07:45   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850908061665562624
# 2017-04-08 22:41:32   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850841064047091713
# 2017-04-08 14:02:40   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850710487599902722
# 2017-04-08 13:34:56   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850703510152896512
# 2017-04-08 13:09:44   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850697166851117056
# 2017-04-08 09:46:18   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850645971214057472
# 2017-04-08 09:21:22   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850639697420234753
# 2017-04-08 06:30:26   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850596680357613568
# 2017-04-08 06:05:54   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850590507722035201
# 2017-04-08 04:15:27   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850562711641440256
# 2017-04-08 04:14:51   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850562560227147776
# 2017-04-08 00:54:59   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850512261298966528
# 2017-04-08 00:32:25   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850506582408429569
# 2017-04-08 00:28:29   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850505590703050752
# 2017-04-07 23:18:40   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850488020662931456
# 2017-04-07 23:02:18   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850483902804250625
# 2017-04-07 22:53:36   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850481713851633665
# 2017-04-07 22:42:40   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850478960693592064
# 2017-04-07 22:41:16   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850478608871247876
# 2017-04-07 22:39:24   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850478141642596353
# 2017-04-07 22:38:28   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850477904416968704
# 2017-04-07 19:06:45   RT @RobertPicardo: Hilarious.  Andy Borowitz, Latest Stories - The New Yorker https://t.co/PhSyLtYyWO   850424627281219584
# 2017-04-06 22:41:38   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   850116314500927490
# 2017-04-06 13:02:55   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849970677981556736
# 2017-04-06 10:11:46   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849927603695865856
# 2017-04-06 06:18:40   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849868941233070080
# 2017-04-06 05:26:53   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849855910663016448
# 2017-04-06 03:41:35   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849829411138424832
# 2017-04-06 02:54:42   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849817614784372736
# 2017-04-06 02:52:45   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849817121265770496
# 2017-04-06 02:34:11   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849812448962064385
# 2017-04-06 02:32:20   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849811982719037440
# 2017-04-06 02:16:38   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849808035190939648
# 2017-04-06 00:20:38   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849778840968851456
# 2017-04-06 00:14:15   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849777235032764417
# 2017-04-06 00:04:59   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849774903226228737
# 2017-04-05 23:42:15   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849769180068851712
# 2017-04-05 22:56:17   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849757611704459264
# 2017-04-05 22:41:05   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849753786587525120
# 2017-04-05 22:34:16   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849752071918297090
# 2017-04-05 22:23:30   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849749362423058432
# 2017-04-05 22:22:32   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849749119858089986
# 2017-04-05 22:22:07   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849749016393003010
# 2017-04-05 22:21:37   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849748888785346560
# 2017-04-05 22:21:22   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849748827112435716
# 2017-04-05 22:20:41   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849748655615746049
# 2017-04-05 22:20:09   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849748519258914818
# 2017-04-05 22:20:00   RT @stupidpresident: Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents https:/…   849748484349714434
# 2017-04-05 22:19:07   Jared Kushner Says He Read Up on Middle East During Minutes Waiting for Ski Lift #kushielife #stupidpresidents… https://t.co/7bqYRKZSRx   849748259983831045
# 2017-04-01 01:20:03   RT @stupidpresident: Bush Counting Down Days Until He Is No Longer Worst President in History https://t.co/bh6dKRGqKu “I guess you could sa…   847981854384726016
# 2017-03-31 19:27:53   From Andy Borowitz, of the https://t.co/uM05U9u9sO "I got impeached… https://t.co/u2QmWxU7D2   847893229278306304
# 75

# %%
for ids in to_respond_to:
    print(ids)
    api.update_status('Hi, did you know that this website frequently posts fake news?', in_reply_to_status_id = str(ids))
# Out:
# 851470941301293057
# 851455780385574913
# 851215770893918209
# 851113625213222912
# 851053022390235136
# 850949295989694464
# 850940948838100992
# 850929347363880960
# 850928906479783937
# 850928132962099201
# 850923755597688832
# 850919728612876288
# 850917933916278784
# 850913987915128832
# 850912739677659141
# 850912655376343040
# 850911176405819394
# 850910381774036992
# 850909971604795393
# 850909936813035520
# 850909677554724865
# 850909642955923458
# 850908243236974594
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-e13cef61d0b8> in <module>()
#       1 for ids in to_respond_to:
#       2     print(ids)
# ----> 3     api.update_status('Hi, did you know that this website frequently posts fake news?', in_reply_to_status_id = str(ids))
#       4
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/tweepy/api.py in update_status(self, *args, **kwargs)
#     192             allowed_param=['status', 'in_reply_to_status_id', 'lat', 'long', 'source', 'place_id', 'display_coordinates'],
#     193             require_auth=True
# --> 194         )(post_data=post_data, *args, **kwargs)
#     195
#     196     def media_upload(self, filename, *args, **kwargs):
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/tweepy/binder.py in execute(self)
#     185                                                 timeout=self.api.timeout,
#     186                                                 auth=auth,
# --> 187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
#     189                     raise TweepError('Failed to send request: %s' % e)
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     842         # Force connect early to allow us to validate the connection.
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#     846         if not conn.is_verified:
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:

# %%
for remove in to_respond_to:
    api.destroy_status(remove)
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-29-622400a47801> in <module>()
#       1 for remove in to_respond_to:
# ----> 2     api.destroy_status(remove)
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /Users/elliotgoldingfrank/anaconda/lib/python3.5/site-packages/tweepy/binder.py in execute(self)
#     227                     raise RateLimitError(error_msg, resp)
#     228                 else:
# --> 229                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     230
#     231             # Parse the response payload
#
# TweepError: [{'message': "You may not delete another user's status.", 'code': 183}]

# %%
# Out:
# [Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='phillipb1956', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/481178585483321344/Rlifo4MT_normal.jpeg', time_zone=None, utc_offset=None, profile_text_color='333333', translator_type='none', location='Lake Jackson, TX', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='749691109', favourites_count=5, friends_count=240, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=68, listed_count=1, geo_enabled=False, verified=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', _json={'listed_count': 1, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/481178585483321344/Rlifo4MT_normal.jpeg', 'notifications': False, 'time_zone': None, 'verified': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'translator_type': 'none', 'profile_background_color': 'C0DEED', 'statuses_count': 12184, 'id': 749691109, 'utc_offset': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/481178585483321344/Rlifo4MT_normal.jpeg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Fri Aug 10 16:58:19 +0000 2012', 'following': False, 'default_profile': True, 'location': 'Lake Jackson, TX', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_border_color': 'C0DEED', 'name': 'phillip', 'profile_text_color': '333333', 'id_str': '749691109', 'favourites_count': 5, 'follow_request_sent': False, 'default_profile_image': False, 'description': 'Many years in industrial construction! Now a professional Networker Marketer! Passionate about health and helping people find financial freedom!', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 68, 'friends_count': 240, 'lang': 'en', 'protected': False, 'screen_name': 'phillipb1956'}, profile_use_background_image=True, profile_background_color='C0DEED', statuses_count=12184, id=749691109, follow_request_sent=False, created_at=datetime.datetime(2012, 8, 10, 16, 58, 19), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='phillip', default_profile_image=False, description='Many years in industrial construction! Now a professional Networker Marketer! Passionate about health and helping people find financial freedom!', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/481178585483321344/Rlifo4MT_normal.jpeg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'fb.me/8tapLeW7U', 'expanded_url': 'http://fb.me/8tapLeW7U', 'url': 'https://t.co/PZdoNkFElQ', 'indices': [86, 109]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 10, 16, 24, 37), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Facebook', user=User(screen_name='phillipb1956', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/481178585483321344/Rlifo4MT_normal.jpeg', time_zone=None, utc_offset=None, profile_text_color='333333', translator_type='none', location='Lake Jackson, TX', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='749691109', favourites_count=5, friend ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='TheresaFKoch', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/465692485553901569/8oMzrqD1_normal.jpeg', time_zone='Pacific Time (US & Canada)', profile_banner_url='https://pbs.twimg.com/profile_banners/24637140/1399864650', utc_offset=-25200, profile_text_color='666666', translator_type='none', location='Earth', profile_background_image_url='http://abs.twimg.com/images/themes/theme9/bg.gif', profile_sidebar_border_color='181A1E', id_str='24637140', favourites_count=3, friends_count=1796, following=False, has_extended_profile=False, entities={'description': {'urls': []}, 'url': {'urls': [{'display_url': 'paranormalphotos.tripod.com', 'expanded_url': 'http://paranormalphotos.tripod.com/', 'url': 'http://t.co/0DWkN3ORot', 'indices': [0, 22]}]}}, protected=False, followers_count=884, listed_count=34, geo_enabled=True, verified=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme9/bg.gif', _json={'translator_type': 'none', 'listed_count': 34, 'is_translator': False, 'geo_enabled': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/465692485553901569/8oMzrqD1_normal.jpeg', 'notifications': False, 'time_zone': 'Pacific Time (US & Canada)', 'verified': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_sidebar_fill_color': '252429', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/24637140/1399864650', 'profile_background_color': '1A1B1F', 'statuses_count': 39233, 'id': 24637140, 'utc_offset': -25200, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/465692485553901569/8oMzrqD1_normal.jpeg', 'is_translation_enabled': False, 'profile_link_color': '2FC2EF', 'created_at': 'Mon Mar 16 02:47:42 +0000 2009', 'following': False, 'default_profile': False, 'location': 'Earth', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_sidebar_border_color': '181A1E', 'name': 'Theresa F Koch', 'profile_text_color': '666666', 'id_str': '24637140', 'favourites_count': 3, 'follow_request_sent': False, 'default_profile_image': False, 'description': 'Theresa F. Koch holds her Masters in the Science of Parapsychic Science and has worked in the paranormal field for over 3 decades.', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': 'http://t.co/0DWkN3ORot', 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}, 'url': {'urls': [{'display_url': 'paranormalphotos.tripod.com', 'expanded_url': 'http://paranormalphotos.tripod.com/', 'url': 'http://t.co/0DWkN3ORot', 'indices': [0, 22]}]}}, 'followers_count': 884, 'friends_count': 1796, 'lang': 'en', 'protected': False, 'screen_name': 'TheresaFKoch'}, profile_use_background_image=True, profile_background_color='1A1B1F', statuses_count=39233, id=24637140, follow_request_sent=False, created_at=datetime.datetime(2009, 3, 16, 2, 47, 42), default_profile=False, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='252429', is_translation_enabled=False, name='Theresa F Koch', default_profile_image=False, description='Theresa F. Koch holds her Masters in the Science of Parapsychic Science and has worked in the paranormal field for over 3 decades.', profile_background_tile=False, url='http://t.co/0DWkN3ORot', profile_link_color='2FC2EF', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/465692485553901569/8oMzrqD1_normal.jpeg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'fb.me/8UI4dD3aD', 'expanded_url': 'http://fb.me/8UI4dD3aD', 'url': 'https://t.co/Pz7kK8Efy7', 'indices': [78, 101]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 10, 3, ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='Eat_shit_obama', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/847288700543287296/8HcnDw5A_normal.jpg', time_zone='Pacific Time (US & Canada)', profile_banner_url='https://pbs.twimg.com/profile_banners/299945488/1466628351', utc_offset=-25200, profile_text_color='333333', translator_type='none', location='Dumbfuckistan cali', profile_background_image_url='http://pbs.twimg.com/profile_background_images/860590707/5e4f890fb1fbd4cfe28bbffbcf02aa37.jpeg', profile_sidebar_border_color='FFFFFF', id_str='299945488', favourites_count=585, friends_count=8931, following=False, has_extended_profile=True, entities={'description': {'urls': []}}, protected=False, followers_count=8950, listed_count=169, geo_enabled=True, verified=False, profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/860590707/5e4f890fb1fbd4cfe28bbffbcf02aa37.jpeg', _json={'translator_type': 'none', 'listed_count': 169, 'is_translator': False, 'geo_enabled': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/847288700543287296/8HcnDw5A_normal.jpg', 'notifications': False, 'time_zone': 'Pacific Time (US & Canada)', 'verified': False, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/860590707/5e4f890fb1fbd4cfe28bbffbcf02aa37.jpeg', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/299945488/1466628351', 'profile_background_color': '642D8B', 'statuses_count': 89502, 'id': 299945488, 'utc_offset': -25200, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/847288700543287296/8HcnDw5A_normal.jpg', 'is_translation_enabled': False, 'profile_link_color': 'FF0000', 'created_at': 'Mon May 16 23:11:25 +0000 2011', 'following': False, 'default_profile': False, 'location': 'Dumbfuckistan cali', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/860590707/5e4f890fb1fbd4cfe28bbffbcf02aa37.jpeg', 'profile_sidebar_border_color': 'FFFFFF', 'name': 'LiberalCrusher', 'profile_text_color': '333333', 'id_str': '299945488', 'favourites_count': 585, 'follow_request_sent': False, 'default_profile_image': False, 'description': "I voted for #Trump don't like that kiss my Ass. PC people go to Hell piss off liberals & millennials #Dodgers #MILITARY #POLICE #Pelicans", 'profile_background_tile': True, 'profile_use_background_image': False, 'url': None, 'contributors_enabled': False, 'has_extended_profile': True, 'entities': {'description': {'urls': []}}, 'followers_count': 8950, 'friends_count': 8931, 'lang': 'en', 'protected': False, 'screen_name': 'Eat_shit_obama'}, profile_use_background_image=False, profile_background_color='642D8B', statuses_count=89502, id=299945488, follow_request_sent=False, created_at=datetime.datetime(2011, 5, 16, 23, 11, 25), default_profile=False, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='LiberalCrusher', default_profile_image=False, description="I voted for #Trump don't like that kiss my Ass. PC people go to Hell piss off liberals & millennials #Dodgers #MILITARY #POLICE #Pelicans", profile_background_tile=True, url=None, profile_link_color='FF0000', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/847288700543287296/8HcnDw5A_normal.jpg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'americannews.com/view-deserves-…', 'expanded_url': 'http://americannews.com/view-deserves-permanently-cancelled/', 'url': 'https://t.co/5UhZboYdcX', 'indices': [117, 140]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 9, 23, 49, 29), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Twit ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='childofgod7862', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/428218977546809344/Uyxp5JVD_normal.jpeg', time_zone=None, profile_banner_url='https://pbs.twimg.com/profile_banners/2315822527/1390930309', utc_offset=None, profile_text_color='333333', translator_type='none', location='Van Buren Arkansas ', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='2315822527', favourites_count=144, friends_count=165, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=35, listed_count=0, geo_enabled=True, verified=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', _json={'translator_type': 'none', 'listed_count': 0, 'is_translator': False, 'geo_enabled': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/428218977546809344/Uyxp5JVD_normal.jpeg', 'notifications': False, 'time_zone': None, 'verified': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2315822527/1390930309', 'profile_background_color': 'C0DEED', 'statuses_count': 21381, 'id': 2315822527, 'utc_offset': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/428218977546809344/Uyxp5JVD_normal.jpeg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Tue Jan 28 17:18:58 +0000 2014', 'following': False, 'default_profile': True, 'location': 'Van Buren Arkansas ', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_border_color': 'C0DEED', 'name': 'Anna', 'profile_text_color': '333333', 'id_str': '2315822527', 'favourites_count': 144, 'follow_request_sent': False, 'default_profile_image': False, 'description': '', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 35, 'friends_count': 165, 'lang': 'en', 'protected': False, 'screen_name': 'childofgod7862'}, profile_use_background_image=True, profile_background_color='C0DEED', statuses_count=21381, id=2315822527, follow_request_sent=False, created_at=datetime.datetime(2014, 1, 28, 17, 18, 58), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='Anna', default_profile_image=False, description='', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/428218977546809344/Uyxp5JVD_normal.jpeg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'fb.me/4DXI2srmY', 'expanded_url': 'http://fb.me/4DXI2srmY', 'url': 'https://t.co/VV9VA3EJ0B', 'indices': [73, 96]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 9, 23, 27, 12), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Facebook', user=User(screen_name='childofgod7862', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/428218977546809344/Uyxp5JVD_normal.jpeg', time_zone=None, profile_banner_url='https://pbs.twimg.com/profile_banners/2315822527/1390930309', utc_offset=None, profile_text_color='333333', translator_type='none', location='Van Buren Arkansas ', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='2315822527', favourites_count=144, friends_count=165, following= ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='jaynie_miller', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/830969048607264769/HvLzAUTU_normal.jpg', time_zone=None, profile_banner_url='https://pbs.twimg.com/profile_banners/830962237376389120/1486953497', utc_offset=None, profile_text_color='333333', translator_type='none', location='', profile_background_image_url=None, profile_sidebar_border_color='C0DEED', id_str='830962237376389120', favourites_count=6, friends_count=16, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=0, listed_count=0, geo_enabled=False, verified=False, profile_background_image_url_https=None, _json={'translator_type': 'none', 'listed_count': 0, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/830969048607264769/HvLzAUTU_normal.jpg', 'notifications': False, 'time_zone': None, 'verified': False, 'profile_background_image_url_https': None, 'profile_sidebar_fill_color': 'DDEEF6', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/830962237376389120/1486953497', 'profile_background_color': 'F5F8FA', 'statuses_count': 3, 'id': 830962237376389120, 'utc_offset': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830969048607264769/HvLzAUTU_normal.jpg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Mon Feb 13 02:10:10 +0000 2017', 'following': False, 'default_profile': True, 'location': '', 'profile_background_image_url': None, 'profile_sidebar_border_color': 'C0DEED', 'name': 'Jaynie Marie Miller', 'profile_text_color': '333333', 'id_str': '830962237376389120', 'favourites_count': 6, 'follow_request_sent': False, 'default_profile_image': False, 'description': '', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 0, 'friends_count': 16, 'lang': 'en', 'protected': False, 'screen_name': 'jaynie_miller'}, profile_use_background_image=True, profile_background_color='F5F8FA', statuses_count=3, id=830962237376389120, follow_request_sent=False, created_at=datetime.datetime(2017, 2, 13, 2, 10, 10), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='Jaynie Marie Miller', default_profile_image=False, description='', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/830969048607264769/HvLzAUTU_normal.jpg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'americannews.com/nancy-pelosi-s…', 'expanded_url': 'http://americannews.com/nancy-pelosi-shut-trump-immediately-destroys-brutal-presidential-response/', 'url': 'https://t.co/uxELXF45sC', 'indices': [90, 113]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 9, 23, 14, 47), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Twitter Web Client', user=User(screen_name='jaynie_miller', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/830969048607264769/HvLzAUTU_normal.jpg', time_zone=None, profile_banner_url='https://pbs.twimg.com/profile_banners/830962237376389120/1486953497', utc_offset=None, profile_text_color='333333', translator_type='none', location='', profile_background_image_url=None, profile_sidebar_border_color='C0DEED', id_str='830962237376389120', favourites_count=6, friends_count=16, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=0, listed ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='rwood2477', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/789578793551859712/I_VAyNAs_normal.jpg', time_zone=None, utc_offset=None, profile_text_color='333333', translator_type='none', location='West Allis, Wisconsin', profile_background_image_url=None, profile_sidebar_border_color='C0DEED', id_str='789573892641845249', favourites_count=2434, friends_count=88, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=60, listed_count=2, geo_enabled=False, verified=False, profile_background_image_url_https=None, _json={'listed_count': 2, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/789578793551859712/I_VAyNAs_normal.jpg', 'notifications': False, 'time_zone': None, 'verified': False, 'profile_background_image_url_https': None, 'profile_sidebar_fill_color': 'DDEEF6', 'translator_type': 'none', 'profile_background_color': 'F5F8FA', 'statuses_count': 5673, 'id': 789573892641845249, 'utc_offset': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/789578793551859712/I_VAyNAs_normal.jpg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Fri Oct 21 21:07:40 +0000 2016', 'following': False, 'default_profile': True, 'location': 'West Allis, Wisconsin', 'profile_background_image_url': None, 'profile_sidebar_border_color': 'C0DEED', 'name': 'Rod Wood', 'profile_text_color': '333333', 'id_str': '789573892641845249', 'favourites_count': 2434, 'follow_request_sent': False, 'default_profile_image': False, 'description': 'Retired', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 60, 'friends_count': 88, 'lang': 'en', 'protected': False, 'screen_name': 'rwood2477'}, profile_use_background_image=True, profile_background_color='F5F8FA', statuses_count=5673, id=789573892641845249, follow_request_sent=False, created_at=datetime.datetime(2016, 10, 21, 21, 7, 40), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='Rod Wood', default_profile_image=False, description='Retired', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/789578793551859712/I_VAyNAs_normal.jpg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'americannews.com/breaking-morga…', 'expanded_url': 'http://americannews.com/breaking-morgan-freeman-risks-entire-career-back-trump-heroic-way/', 'url': 'https://t.co/4Zt2UycxuS', 'indices': [77, 100]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 9, 22, 28, 56), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Twitter Web Client', user=User(screen_name='rwood2477', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/789578793551859712/I_VAyNAs_normal.jpg', time_zone=None, utc_offset=None, profile_text_color='333333', translator_type='none', location='West Allis, Wisconsin', profile_background_image_url=None, profile_sidebar_border_color='C0DEED', id_str='789573892641845249', favourites_count=2434, friends_count=88, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=60, listed_count=2, geo_enabled=False, verified=False, profile_background_image_url_https=None, _json={'listed_count': 2, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/789 ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='dbarton05', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', time_zone=None, profile_banner_url='https://pbs.twimg.com/profile_banners/1962873763/1485005514', utc_offset=None, profile_text_color='333333', translator_type='none', location='Michigan', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='1962873763', favourites_count=1030, friends_count=1552, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=1326, listed_count=59, geo_enabled=False, verified=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', _json={'translator_type': 'none', 'listed_count': 59, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', 'notifications': False, 'time_zone': None, 'verified': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1962873763/1485005514', 'profile_background_color': 'C0DEED', 'statuses_count': 25337, 'id': 1962873763, 'utc_offset': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Tue Oct 15 15:09:26 +0000 2013', 'following': False, 'default_profile': True, 'location': 'Michigan', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_border_color': 'C0DEED', 'name': 'Deplorable Don', 'profile_text_color': '333333', 'id_str': '1962873763', 'favourites_count': 1030, 'follow_request_sent': False, 'default_profile_image': False, 'description': 'Vietnam Veteran that supports Donald J Trump as The President of the United States!!!  #America First  #Make America Great Again  #Make America Safe Again', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 1326, 'friends_count': 1552, 'lang': 'en', 'protected': False, 'screen_name': 'dbarton05'}, profile_use_background_image=True, profile_background_color='C0DEED', statuses_count=25337, id=1962873763, follow_request_sent=False, created_at=datetime.datetime(2013, 10, 15, 15, 9, 26), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='Deplorable Don', default_profile_image=False, description='Vietnam Veteran that supports Donald J Trump as The President of the United States!!!  #America First  #Make America Great Again  #Make America Safe Again', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'ln.is/americannews.c…', 'expanded_url': 'http://ln.is/americannews.com/YdVZh', 'url': 'https://t.co/bD5sYyXPzS', 'indices': [65, 88]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 9, 20, 20, 16), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Linkis: turn sharing into growth', user=User(screen_name='dbarton05', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', time_zone=None, profile_banner_url='https://pbs.twi ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='dbarton05', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', time_zone=None, profile_banner_url='https://pbs.twimg.com/profile_banners/1962873763/1485005514', utc_offset=None, profile_text_color='333333', translator_type='none', location='Michigan', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='1962873763', favourites_count=1030, friends_count=1552, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=1326, listed_count=59, geo_enabled=False, verified=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', _json={'translator_type': 'none', 'listed_count': 59, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', 'notifications': False, 'time_zone': None, 'verified': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1962873763/1485005514', 'profile_background_color': 'C0DEED', 'statuses_count': 25337, 'id': 1962873763, 'utc_offset': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Tue Oct 15 15:09:26 +0000 2013', 'following': False, 'default_profile': True, 'location': 'Michigan', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_border_color': 'C0DEED', 'name': 'Deplorable Don', 'profile_text_color': '333333', 'id_str': '1962873763', 'favourites_count': 1030, 'follow_request_sent': False, 'default_profile_image': False, 'description': 'Vietnam Veteran that supports Donald J Trump as The President of the United States!!!  #America First  #Make America Great Again  #Make America Safe Again', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 1326, 'friends_count': 1552, 'lang': 'en', 'protected': False, 'screen_name': 'dbarton05'}, profile_use_background_image=True, profile_background_color='C0DEED', statuses_count=25337, id=1962873763, follow_request_sent=False, created_at=datetime.datetime(2013, 10, 15, 15, 9, 26), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='Deplorable Don', default_profile_image=False, description='Vietnam Veteran that supports Donald J Trump as The President of the United States!!!  #America First  #Make America Great Again  #Make America Safe Again', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'ln.is/americannews.c…', 'expanded_url': 'http://ln.is/americannews.com/RncAE', 'url': 'https://t.co/xLDwLneLxN', 'indices': [73, 96]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 9, 20, 19, 42), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Linkis: turn sharing into growth', user=User(screen_name='dbarton05', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', time_zone=None, profile_banner_url='https://pbs.twi ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='JMH2770', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/438015075190730752/68tTJeNr_normal.jpeg', time_zone='Central Time (US & Canada)', utc_offset=-18000, profile_text_color='333333', translator_type='none', location='Huntley, IL', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='904045632', favourites_count=1, friends_count=9, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=4, listed_count=0, geo_enabled=False, verified=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', _json={'listed_count': 0, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/438015075190730752/68tTJeNr_normal.jpeg', 'notifications': False, 'time_zone': 'Central Time (US & Canada)', 'verified': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'translator_type': 'none', 'profile_background_color': 'C0DEED', 'statuses_count': 3226, 'id': 904045632, 'utc_offset': -18000, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/438015075190730752/68tTJeNr_normal.jpeg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Thu Oct 25 14:52:06 +0000 2012', 'following': False, 'default_profile': True, 'location': 'Huntley, IL', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_border_color': 'C0DEED', 'name': 'Jim Harter', 'profile_text_color': '333333', 'id_str': '904045632', 'favourites_count': 1, 'follow_request_sent': False, 'default_profile_image': False, 'description': 'Proud Christian, and Conservative American.', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 4, 'friends_count': 9, 'lang': 'en', 'protected': False, 'screen_name': 'JMH2770'}, profile_use_background_image=True, profile_background_color='C0DEED', statuses_count=3226, id=904045632, follow_request_sent=False, created_at=datetime.datetime(2012, 10, 25, 14, 52, 6), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='Jim Harter', default_profile_image=False, description='Proud Christian, and Conservative American.', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/438015075190730752/68tTJeNr_normal.jpeg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'fb.me/68bHxO26k', 'expanded_url': 'http://fb.me/68bHxO26k', 'url': 'https://t.co/4OGAJ2m4pc', 'indices': [111, 134]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 9, 17, 29, 46), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Facebook', user=User(screen_name='JMH2770', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/438015075190730752/68tTJeNr_normal.jpeg', time_zone='Central Time (US & Canada)', utc_offset=-18000, profile_text_color='333333', translator_type='none', location='Huntley, IL', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='904045632', favourites_count=1, friends_count=9, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=4, listed_count=0, geo_enab ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='dbarton05', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', time_zone=None, profile_banner_url='https://pbs.twimg.com/profile_banners/1962873763/1485005514', utc_offset=None, profile_text_color='333333', translator_type='none', location='Michigan', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='1962873763', favourites_count=1030, friends_count=1552, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=1326, listed_count=59, geo_enabled=False, verified=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', _json={'translator_type': 'none', 'listed_count': 59, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', 'notifications': False, 'time_zone': None, 'verified': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1962873763/1485005514', 'profile_background_color': 'C0DEED', 'statuses_count': 25337, 'id': 1962873763, 'utc_offset': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Tue Oct 15 15:09:26 +0000 2013', 'following': False, 'default_profile': True, 'location': 'Michigan', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_border_color': 'C0DEED', 'name': 'Deplorable Don', 'profile_text_color': '333333', 'id_str': '1962873763', 'favourites_count': 1030, 'follow_request_sent': False, 'default_profile_image': False, 'description': 'Vietnam Veteran that supports Donald J Trump as The President of the United States!!!  #America First  #Make America Great Again  #Make America Safe Again', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 1326, 'friends_count': 1552, 'lang': 'en', 'protected': False, 'screen_name': 'dbarton05'}, profile_use_background_image=True, profile_background_color='C0DEED', statuses_count=25337, id=1962873763, follow_request_sent=False, created_at=datetime.datetime(2013, 10, 15, 15, 9, 26), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='Deplorable Don', default_profile_image=False, description='Vietnam Veteran that supports Donald J Trump as The President of the United States!!!  #America First  #Make America Great Again  #Make America Safe Again', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'ln.is/americannews.c…', 'expanded_url': 'http://ln.is/americannews.com/NFsSq', 'url': 'https://t.co/9TfDRIXBaH', 'indices': [81, 104]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 9, 11, 53, 28), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Linkis: turn sharing into growth', user=User(screen_name='dbarton05', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/709808203937226756/eB33vza6_normal.jpg', time_zone=None, profile_banner_url='https://pbs.tw ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='AllenLOse', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/378800000817950854/9b4fbcdf931732c4b74b3bf2b316710c_normal.jpeg', time_zone='Central Time (US & Canada)', utc_offset=-18000, profile_text_color='333333', translator_type='none', location='', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='2225708558', favourites_count=806, friends_count=1491, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=1502, listed_count=11, geo_enabled=False, verified=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', _json={'listed_count': 11, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000817950854/9b4fbcdf931732c4b74b3bf2b316710c_normal.jpeg', 'notifications': False, 'time_zone': 'Central Time (US & Canada)', 'verified': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'translator_type': 'none', 'profile_background_color': 'C0DEED', 'statuses_count': 7305, 'id': 2225708558, 'utc_offset': -18000, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000817950854/9b4fbcdf931732c4b74b3bf2b316710c_normal.jpeg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Sun Dec 01 23:05:09 +0000 2013', 'following': False, 'default_profile': True, 'location': '', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_border_color': 'C0DEED', 'name': 'Allen L. Ose', 'profile_text_color': '333333', 'id_str': '2225708558', 'favourites_count': 806, 'follow_request_sent': False, 'default_profile_image': False, 'description': 'I love our Constitution therefore I am a member of TEA Parties. I dislike communism so I try to help eliminate the IRS & 16th Amendment and the Federal Reserve', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 1502, 'friends_count': 1491, 'lang': 'en', 'protected': False, 'screen_name': 'AllenLOse'}, profile_use_background_image=True, profile_background_color='C0DEED', statuses_count=7305, id=2225708558, follow_request_sent=False, created_at=datetime.datetime(2013, 12, 1, 23, 5, 9), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='Allen L. Ose', default_profile_image=False, description='I love our Constitution therefore I am a member of TEA Parties. I dislike communism so I try to help eliminate the IRS & 16th Amendment and the Federal Reserve', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/378800000817950854/9b4fbcdf931732c4b74b3bf2b316710c_normal.jpeg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'americannews.com/ann-coulter-sp…', 'expanded_url': 'http://americannews.com/ann-coulter-sparks-national-outrage-exposing-shocking-secret-muslim-refugees/', 'url': 'https://t.co/INmU0BmryS', 'indices': [94, 117]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 8, 23, 19, 57), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Twitter Web Client', user=User(screen_name='AllenLOse', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/378800000817950854/9b4fbcdf931732c4b74b3bf2b316710c_normal. ...
# ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='perrisgirl1', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/815822462050938880/kpP1i67H_normal.jpg', time_zone='Pacific Time (US & Canada)', profile_banner_url='https://pbs.twimg.com/profile_banners/37579226/1485152489', utc_offset=-25200, profile_text_color='F5DD5B', translator_type='none', location='', profile_background_image_url='http://pbs.twimg.com/profile_background_images/874974922/b2651e36a11886463d223746b5f556da.gif', profile_sidebar_border_color='000000', id_str='37579226', favourites_count=45722, friends_count=4369, following=False, has_extended_profile=True, entities={'description': {'urls': []}}, protected=False, followers_count=2745, listed_count=46, geo_enabled=False, verified=False, profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/874974922/b2651e36a11886463d223746b5f556da.gif', _json={'translator_type': 'none', 'listed_count': 46, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/815822462050938880/kpP1i67H_normal.jpg', 'notifications': False, 'time_zone': 'Pacific Time (US & Canada)', 'verified': False, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/874974922/b2651e36a11886463d223746b5f556da.gif', 'profile_sidebar_fill_color': 'F2E6A6', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/37579226/1485152489', 'profile_background_color': 'F50C18', 'statuses_count': 40122, 'id': 37579226, 'utc_offset': -25200, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/815822462050938880/kpP1i67H_normal.jpg', 'is_translation_enabled': False, 'profile_link_color': 'FAB81E', 'created_at': 'Mon May 04 03:03:08 +0000 2009', 'following': False, 'default_profile': False, 'location': '', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/874974922/b2651e36a11886463d223746b5f556da.gif', 'profile_sidebar_border_color': '000000', 'name': 'wendy harrington🇺🇸', 'profile_text_color': 'F5DD5B', 'id_str': '37579226', 'favourites_count': 45722, 'follow_request_sent': False, 'default_profile_image': False, 'description': 'NOT a alt-right racist but am a Trump train rider.. NO LISTS. Animals are better than MOST people.', 'profile_background_tile': True, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': True, 'entities': {'description': {'urls': []}}, 'followers_count': 2745, 'friends_count': 4369, 'lang': 'en', 'protected': False, 'screen_name': 'perrisgirl1'}, profile_use_background_image=True, profile_background_color='F50C18', statuses_count=40122, id=37579226, follow_request_sent=False, created_at=datetime.datetime(2009, 5, 4, 3, 3, 8), default_profile=False, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='F2E6A6', is_translation_enabled=False, name='wendy harrington🇺🇸', default_profile_image=False, description='NOT a alt-right racist but am a Trump train rider.. NO LISTS. Animals are better than MOST people.', profile_background_tile=True, url=None, profile_link_color='FAB81E', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/815822462050938880/kpP1i67H_normal.jpg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'americannews.com/military-gener…', 'expanded_url': 'http://americannews.com/military-generals-move-to-arrest-obama-after-they-find-proof-he-armed-isis/', 'url': 'https://t.co/Ps13sz9kdP', 'indices': [101, 124]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 4, 19, 16, 27), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Twitter Web Client', user=User(screen_name='perrisgirl1', is_translator=False, contributo ...
#  Status(retweet_count=1, is_quote_status=False, retweeted=False, author=User(screen_name='darstin1957', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/603989947603951616/V54xYzAs_normal.jpg', time_zone=None, utc_offset=None, profile_text_color='333333', translator_type='none', location='', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='3152610784', favourites_count=516, friends_count=363, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=50, listed_count=0, geo_enabled=True, verified=False, profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', _json={'listed_count': 0, 'is_translator': False, 'geo_enabled': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/603989947603951616/V54xYzAs_normal.jpg', 'notifications': False, 'time_zone': None, 'verified': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_fill_color': 'DDEEF6', 'translator_type': 'none', 'profile_background_color': 'C0DEED', 'statuses_count': 914, 'id': 3152610784, 'utc_offset': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/603989947603951616/V54xYzAs_normal.jpg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Thu Apr 09 19:29:32 +0000 2015', 'following': False, 'default_profile': True, 'location': '', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_sidebar_border_color': 'C0DEED', 'name': 'darstin @. com 1957', 'profile_text_color': '333333', 'id_str': '3152610784', 'favourites_count': 516, 'follow_request_sent': False, 'default_profile_image': False, 'description': '', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 50, 'friends_count': 363, 'lang': 'en', 'protected': False, 'screen_name': 'darstin1957'}, profile_use_background_image=True, profile_background_color='C0DEED', statuses_count=914, id=3152610784, follow_request_sent=False, created_at=datetime.datetime(2015, 4, 9, 19, 29, 32), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='darstin @. com 1957', default_profile_image=False, description='', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/603989947603951616/V54xYzAs_normal.jpg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'americannews.com/judge-jeanine-…', 'expanded_url': 'http://americannews.com/judge-jeanine-pirro-goes-rips-michelle-obama-limb-limb-live-tv/', 'url': 'https://t.co/HlqJTu1A7j', 'indices': [79, 102]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 4, 18, 18, 57), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Twitter for Android', user=User(screen_name='darstin1957', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/603989947603951616/V54xYzAs_normal.jpg', time_zone=None, utc_offset=None, profile_text_color='333333', translator_type='none', location='', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_sidebar_border_color='C0DEED', id_str='3152610784', favourites_count=516, friends_count=363, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=50, listed_count=0, geo_enabled=True, verified=False, profile_background_image_url_https='htt ...
#  Status(retweet_count=0, is_quote_status=False, retweeted=False, author=User(screen_name='Svonsunkel', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/847807160880959495/EEPI0Zjl_normal.jpg', time_zone=None, profile_banner_url='https://pbs.twimg.com/profile_banners/834930165151117314/1490968191', utc_offset=None, profile_text_color='333333', translator_type='none', location='', profile_background_image_url=None, profile_sidebar_border_color='C0DEED', id_str='834930165151117314', favourites_count=265, friends_count=13, following=False, has_extended_profile=False, entities={'description': {'urls': []}}, protected=False, followers_count=8, listed_count=0, geo_enabled=False, verified=False, profile_background_image_url_https=None, _json={'translator_type': 'none', 'listed_count': 0, 'is_translator': False, 'geo_enabled': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/847807160880959495/EEPI0Zjl_normal.jpg', 'notifications': False, 'time_zone': None, 'verified': False, 'profile_background_image_url_https': None, 'profile_sidebar_fill_color': 'DDEEF6', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/834930165151117314/1490968191', 'profile_background_color': 'F5F8FA', 'statuses_count': 289, 'id': 834930165151117314, 'utc_offset': None, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/847807160880959495/EEPI0Zjl_normal.jpg', 'is_translation_enabled': False, 'profile_link_color': '1DA1F2', 'created_at': 'Fri Feb 24 00:57:18 +0000 2017', 'following': False, 'default_profile': True, 'location': '', 'profile_background_image_url': None, 'profile_sidebar_border_color': 'C0DEED', 'name': 'Slv', 'profile_text_color': '333333', 'id_str': '834930165151117314', 'favourites_count': 265, 'follow_request_sent': False, 'default_profile_image': False, 'description': 'Love the Lord.  Love your country...and Oreo cookies.  : )', 'profile_background_tile': False, 'profile_use_background_image': True, 'url': None, 'contributors_enabled': False, 'has_extended_profile': False, 'entities': {'description': {'urls': []}}, 'followers_count': 8, 'friends_count': 13, 'lang': 'en', 'protected': False, 'screen_name': 'Svonsunkel'}, profile_use_background_image=True, profile_background_color='F5F8FA', statuses_count=289, id=834930165151117314, follow_request_sent=False, created_at=datetime.datetime(2017, 2, 24, 0, 57, 18), default_profile=True, _api=<tweepy.api.API object at 0x1076f0cc0>, notifications=False, profile_sidebar_fill_color='DDEEF6', is_translation_enabled=False, name='Slv', default_profile_image=False, description='Love the Lord.  Love your country...and Oreo cookies.  : )', profile_background_tile=False, url=None, profile_link_color='1DA1F2', lang='en', profile_image_url_https='https://pbs.twimg.com/profile_images/847807160880959495/EEPI0Zjl_normal.jpg'), coordinates=None, entities={'user_mentions': [], 'hashtags': [], 'urls': [{'display_url': 'americannews.com/watch-happens-…', 'expanded_url': 'http://americannews.com/watch-happens-muslims-tried-force-sharia-law-americans-big-mistake/', 'url': 'https://t.co/uOzoyqDxe7', 'indices': [35, 58]}], 'symbols': []}, favorited=False, in_reply_to_screen_name=None, geo=None, possibly_sensitive=False, created_at=datetime.datetime(2017, 4, 4, 17, 39, 25), _api=<tweepy.api.API object at 0x1076f0cc0>, in_reply_to_user_id_str=None, source='Twitter for iPhone', user=User(screen_name='Svonsunkel', is_translator=False, contributors_enabled=False, profile_image_url='http://pbs.twimg.com/profile_images/847807160880959495/EEPI0Zjl_normal.jpg', time_zone=None, profile_banner_url='https://pbs.twimg.com/profile_banners/834930165151117314/1490968191', utc_offset=None, profile_text_color='333333', translator_type='none', location='', profile_background_image_url=None, profile_sidebar_border_color='C0DEED', id_str='834930165151117314', favourites_count=265, friends_count=13, following=False, has_extended_profile=False, entit ...

# %% [markdown]
# ------
#
# **Book Bot**
# An activity if there's time: What could we tweet that's interesting about any of the books on the NYT non-fiction list?

# %%
import requests, json
import pandas as pd
url = 'http://api.nytimes.com/svc/books/v3/lists/hardcover-nonfiction.json?api-key=sample-key' 
api_response = requests.get(url).json()
books_data = pd.read_json(json.dumps(api_response["results"]["books"]))
books_data
